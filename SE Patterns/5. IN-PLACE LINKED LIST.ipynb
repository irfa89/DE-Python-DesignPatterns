# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# “Modify the list without extra space”
#
# “Do it in-place”
#
# Singly linked list with next pointers
#
# Reordering, reversing, deleting, or partitioning nodes
#
# Brute force uses arrays / extra lists → ❌ O(n) space

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Is the input a linked list?
#
# Are you asked to change node links (not values)?
#
# Is extra memory disallowed or discouraged?
#
# Do pointers get reassigned (next = ...)?
#
# Does traversal happen once or twice?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Rewire next pointers while traversing the list.
#
# Maintain minimal temporary pointers to avoid losing nodes.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
prev = None
cur = head

while cur:
    nxt = cur.next
    cur.next = prev
    prev = cur
    cur = nxt

return prev

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Full Reverse
#
# Reverse entire list
#
# Template as-is
#
# Reverse Sublist
#
# Reverse between positions m and n
#
# Add boundary pointers before and after window
#
# Swap Pairs
#
# Swap every two adjacent nodes
#
# Reverse in fixed-size (k=2) chunks
#
# Reverse K-Group
#
# Reverse every k nodes
#
# Loop + count + partial reverse
#
# Reorder List
#
# L0 → Ln → L1 → Ln-1
#
# Split + reverse second half + merge
#
# Delete Node In-Place
#
# Given only node (not head)
#
# Copy next node data and bypass
#
# Partition List
#
# Nodes < x before ≥ x
#
# Two in-place chains + reconnect

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Input: 1 → 2 → 3 → 4
#
# Steps:
#
# cur=1 → next=2 → reverse link
#
# cur=2 → next=3 → reverse link
#
# cur=3 → next=4 → reverse link
#
# cur=4 → next=None → reverse link
#
# Output: 4 → 3 → 2 → 1

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# 🔹 Full Reverse (Canonical)
#
# Question: Reverse a singly linked list.

# %%
def reverseList(head):
    prev = None
    cur = head

    while cur:
        nxt = cur.next
        cur.next = prev
        prev = cur
        cur = nxt

    return prev

# %% [markdown]
# 🔹 Reverse Sublist (m to n)
#
# What changed: Stop/start boundaries added.

# %%
def reverseBetween(head, m, n):
    dummy = ListNode(0, head)
    prev = dummy

    for _ in range(m - 1):
        prev = prev.next

    cur = prev.next
    for _ in range(n - m):
        nxt = cur.next
        cur.next = nxt.next
        nxt.next = prev.next
        prev.next = nxt

    return dummy.next

# %% [markdown]
# 🔹 Swap Pairs
#
# What changed: Fixed-size (k=2) reverse.

# %%
def swapPairs(head):
    dummy = ListNode(0, head)
    prev = dummy

    while prev.next and prev.next.next:
        a = prev.next
        b = a.next

        prev.next = b
        a.next = b.next
        b.next = a

        prev = a

    return dummy.next

# %% [markdown]
# 🔹 Reverse K-Group
#
# What changed: Count + conditional reverse.

# %%
def reverseKGroup(head, k):
    dummy = ListNode(0, head)
    prev = dummy

    while True:
        tail = prev
        for _ in range(k):
            tail = tail.next
            if not tail:
                return dummy.next

        cur = prev.next
        nxt = cur.next

        for _ in range(k - 1):
            cur.next = nxt.next
            nxt.next = prev.next
            prev.next = nxt
            nxt = cur.next

        prev = cur

# %% [markdown]
# 🔹 Reorder List
#
# What changed: Split → reverse → merge.

# %%
def reorderList(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next

    prev = None
    cur = slow.next
    slow.next = None

    while cur:
        nxt = cur.next
        cur.next = prev
        prev = cur
        cur = nxt

    first, second = head, prev
    while second:
        t1, t2 = first.next, second.next
        first.next = second
        second.next = t1
        first, second = t1, t2

# %% [markdown]
# 🔹 Delete Node In-Place
#
# What changed: No head pointer.

# %%
def deleteNode(node):
    node.val = node.next.val
    node.next = node.next.next

# %% [markdown]
# 🔹 Partition List
#
# What changed: Two chains, same traversal.

# %%
def partition(head, x):
    before = b = ListNode(0)
    after = a = ListNode(0)

    while head:
        if head.val < x:
            b.next = head
            b = b.next
        else:
            a.next = head
            a = a.next
        head = head.next

    a.next = None
    b.next = after.next
    return before.next

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Time: O(n)
#
# Space: O(1)
#
# Worst-case: full traversal with pointer rewiring

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Losing nodes by overwriting next
#
# ✔ Always save nxt first
#
# ❌ Infinite loops
#
# ✔ Advance pointers correctly
#
# ❌ Breaking list boundaries
#
# ✔ Use dummy nodes for head safety
#
# ❌ Mixing values instead of pointers
#
# ✔ Only rewire links, never copy lists
