# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# Problem asks: “generate all subsets,” “power set,” or “all combinations”.
#
# Input size is usually small (n ≤ 15–20) — combinatorial explosion if brute-force.
#
# Brute-force: try every combination manually → O(2^n × n), infeasible for larger n.
#
# Often uses recursion/backtracking or iterative bitmasking.
#
# Look for problems where every element can be included or excluded independently.

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Does the problem ask for all subsets, combinations, or power set?
#
# Are elements distinct or can repeat? (affects duplicates handling)
#
# Is input small enough for 2^n solutions?
#
# Need recursion/backtracking or iterative incremental building?
#
# Are constraints asking for subset sums, subset products, or subset properties?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Start with empty subset → expand by including/excluding each element.
#
# Recursively/iteratively explore all paths to form every possible subset.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
def subsets(nums):
    res = []
    def backtrack(path, index):
        res.append(path[:])
        for i in range(index, len(nums)):
            path.append(nums[i])
            backtrack(path, i + 1)
            path.pop()
    backtrack([], 0)
    return res

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Fixed-length subsets (k-combinations) → pass target length k, only append when len(path) == k.
#
# Subsets with duplicates → sort input, skip duplicates in loop (if i > index and nums[i] == nums[i-1]: continue).
#
# Subset sums / target-based → add sum tracking, only append if sum meets condition.
#
# Iterative construction → start with [[]], for each num: add [curr + [num] for curr in res].
#
# Bitmasking approach → iterate 0..2^n-1, include elements where bit is set.

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Input: nums = [1,2]
#
# Step-by-step:
#
# Start path = [], index = 0 → append []
#
# i = 0 → append 1 → path = [1], index = 1 → append [1]
#
# i = 1 → append 2 → path = [1,2], index = 2 → append [1,2]
#
# backtrack → pop 2 → path = [1] → done
#
# backtrack → pop 1 → path = []
#
# i = 1 → append 2 → path = [2], index = 2 → append [2]
#
# Output: [[], [1], [1,2], [2]]

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# Variation 1: Fixed-length subsets (k-combinations)
#
# Change: Only append when len(path) == k.

# %%
# Question: Generate all subsets of length k
def combine(nums, k):
    res = []
    def backtrack(path, index):
        if len(path) == k:
            res.append(path[:])
            return
        for i in range(index, len(nums)):
            path.append(nums[i])
            backtrack(path, i + 1)
            path.pop()
    backtrack([], 0)
    return res
# Example: combine([1,2,3], 2) → [[1,2],[1,3],[2,3]]

# %% [markdown]
# Variation 2: Subsets with duplicates
#
# Change: Skip duplicates in loop.

# %%
def subsetsWithDup(nums):
    res = []
    nums.sort()
    def backtrack(path, index):
        res.append(path[:])
        for i in range(index, len(nums)):
            if i > index and nums[i] == nums[i-1]:
                continue
            path.append(nums[i])
            backtrack(path, i + 1)
            path.pop()
    backtrack([], 0)
    return res
# Example: [1,2,2] → [[],[1],[1,2],[1,2,2],[2],[2,2]]

# %% [markdown]
# Variation 3: Subset sum / target-based
#
# Change: Track running sum, append only if target met.

# %%
def subsetsSumTarget(nums, target):
    res = []
    def backtrack(path, index, total):
        if total == target:
            res.append(path[:])
        for i in range(index, len(nums)):
            if total + nums[i] > target:
                continue
            path.append(nums[i])
            backtrack(path, i + 1, total + nums[i])
            path.pop()
    backtrack([], 0, 0)
    return res
# Example: nums=[1,2,3], target=3 → [[1,2],[3]]

# %% [markdown]
# Variation 4: Iterative construction
#
# Change: Iterative accumulation instead of recursion.

# %%
def subsetsIter(nums):
    res = [[]]
    for num in nums:
        res += [curr + [num] for curr in res]
    return res
# Example: nums=[1,2] → [[],[1],[2],[1,2]]

# %% [markdown]
# Variation 5: Bitmasking
#
# Change: Use bits to represent inclusion/exclusion.

# %%
def subsetsBitmask(nums):
    n = len(nums)
    res = []
    for mask in range(1<<n):
        subset = [nums[i] for i in range(n) if mask & (1<<i)]
        res.append(subset)
    return res

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Time: O(n × 2^n) → generate 2^n subsets, copy each subset of up to n elements.
#
# Space: O(n × 2^n) → storage for all subsets + recursion stack O(n).
#
# Worst-case: full exploration of all inclusion/exclusion paths.

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Forget to backtrack → path grows incorrectly.
# ✔ Always pop() after recursion.
#
# ❌ Duplicate subsets for repeated elements.
# ✔ Sort + skip duplicates (i > index and nums[i] == nums[i-1]).
#
# ❌ Off-by-one in index → infinite recursion or missing subset.
# ✔ Ensure for i in range(index, len(nums)) with index+1 in recursion.
#
# ❌ Exceed target in sum subset.
# ✔ Track running sum and prune early.
