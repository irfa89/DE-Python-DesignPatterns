# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# Problem involves counting, frequency, or index lookup.
#
# Keywords: first occurrence, last occurrence, pair sum, subarray sum = k, group by, anagram.
#
# Input can be unordered, but fast lookup required.
#
# Brute-force usually O(n²) or O(n³), fails due to time constraints.
#
# Mapping from key → value can simplify repeated computation.

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Do we need fast lookup for elements or counts?
#
# Are we grouping or counting items?
#
# Do we need index tracking?
#
# Are there duplicate checks or pair/subarray sums?
#
# Will brute-force time out?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Store precomputed information in a hash table for O(1) access.
# Use keys to map values, indices, or counts dynamically.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
hash_map = {}
for i, val in enumerate(arr):
    if val in hash_map:
        # update or use existing value
        hash_map[val] += 1
    else:
        # initialize
        hash_map[val] = 1

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Frequency Counting → store counts, increment on each occurrence.
#
# Index Mapping → store first/last index of elements.
#
# Pair/Sum Lookup → check if target - val exists in map.
#
# Sliding Window with Map → count frequencies within moving window.
#
# Group By Key → key maps to list of items (like anagrams).
#
# Prefix Sum Mapping → cumulative sums mapped to index/count.

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Problem: Count frequency of elements in [1,2,2,3,3,3].

# %%
arr = [1,2,2,3,3,3]
hash_map = {}
for val in arr:
    if val in hash_map:
        hash_map[val] += 1
    else:
        hash_map[val] = 1

print(hash_map)  # {1:1, 2:2, 3:3}

# %% [markdown]
# Step-by-step:
#
# 1 → hash_map {1:1}
#
# 2 → hash_map {1:1,2:1}
#
# 2 → hash_map {1:1,2:2}
#
# 3 → hash_map {1:1,2:2,3:1}
#
# 3 → hash_map {1:1,2:2,3:2}
#
# 3 → hash_map {1:1,2:2,3:3}

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# 1️⃣ Frequency Counting
#
# Q: Count how many times each character appears in "abbccc"
#
# Variation: frequency → use .get(key,0)+1

# %%
s = "abbccc"
hash_map = {}
for c in s:
    hash_map[c] = hash_map.get(c,0)+1
print(hash_map)  # {'a':1,'b':2,'c':3}

# %% [markdown]
# 2️⃣ Index Mapping
#
# Q: Return first occurrence index of each element [4,2,4,3]
#
# Variation: only store first index → conditional insert

# %%
arr = [4,2,4,3]
hash_map = {}
for i, val in enumerate(arr):
    if val not in hash_map:
        hash_map[val] = i
print(hash_map)  # {4:0,2:1,3:3}

# %% [markdown]
# 3️⃣ Pair/Sum Lookup
#
# Q: Two sum [2,7,11,15], target=9
#
# Variation: check target - val existence

# %%
arr=[2,7,11,15]
target=9
hash_map={}
for i,val in enumerate(arr):
    if target-val in hash_map:
        print([hash_map[target-val],i])  # [0,1]
        break
    hash_map[val]=i

# %% [markdown]
# 4️⃣ Sliding Window with Map
#
# Q: Longest substring without repeating characters "abcabcbb"
#
# Variation: window start moves on duplicate

# %%
s="abcabcbb"
hash_map={}
l=0
res=0
for r,c in enumerate(s):
    if c in hash_map and hash_map[c]>=l:
        l=hash_map[c]+1
    hash_map[c]=r
    res=max(res,r-l+1)
print(res)  # 3

# %% [markdown]
# 5️⃣ Group By Key
#
# Q: Group anagrams ["bat","tab","eat"]
#
# Variation: key maps to list, not count

# %%
words=["bat","tab","eat"]
hash_map={}
for w in words:
    key = tuple(sorted(w))
    hash_map[key] = hash_map.get(key,[])+[w]
print(list(hash_map.values()))  # [['bat','tab'],['eat']]

# %% [markdown]
# 6️⃣ Prefix Sum Mapping
#
# Q: Subarray sum equals k [1,2,3], k=3
#
# Variation: map cumulative sum → subarray count

# %%
arr=[1,2,3]
k=3
hash_map={0:1}
prefix=0
count=0
for val in arr:
    prefix+=val
    count+=hash_map.get(prefix-k,0)
    hash_map[prefix]=hash_map.get(prefix,0)+1
print(count)  # 2

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Time: O(n) for single pass.
#
# Space: O(n) for hash map storage.
#
# Worst-case: all elements unique → map size = n.

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Overwriting values when should append → use list for grouping.
# ❌ Forgetting .get() → KeyError.
# ❌ Sliding window: forgetting to update left pointer.
# ❌ Pair-sum: inserting before checking → miss solution.
# ✔ Always check existence before update; choose map type carefully.
