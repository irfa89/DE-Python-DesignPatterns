# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# Linked list or sequence traversal with unknown cycle behavior
#
# Keywords: cycle, loop, middle, duplicate, repeating
#
# Input size large → extra space not allowed
#
# Brute force:
#
# Use hash/set to track visited → ❌ O(n) space
#
# Nested traversal → ❌ too slow

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Do elements point to the “next” element?
#
# Can the traversal loop forever?
#
# Do I need cycle detection without extra memory?
#
# Can two pointers move at different speeds?
#
# Is the answer related to where they meet?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Move one pointer 1 step, the other 2 steps.
#
# If they meet, a cycle or structural property exists.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
slow = fast = head
while fast and fast.next:
    slow = slow.next
    fast = fast.next.next
    if slow == fast:
        break

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Cycle Detection (Exists?)
#
# Appears when checking infinite loops
#
# Stop when pointers meet
#
# Find Cycle Start
#
# Asked after confirming a cycle
#
# Reset one pointer to head
#
# Find Middle of Linked List
#
# Asked for splitting or reordering
#
# Stop when fast reaches end
#
# Happy Number / Sequence Cycle
#
# Numbers transform repeatedly
#
# Pointer moves via function, not next
#
# Find Duplicate Number (Floyd)
#
# Array treated as linked list
#
# Indices act as pointers

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Input: 1 → 2 → 3 → 4 → 5 → 3
#
# slow: 1 → 2 → 3 → 4
#
# fast: 1 → 3 → 5 → 4
#
# Meet at node 4
#
# Output: Cycle detected

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# ✅ Variation 1: Cycle Detection (Exists?)
#
# Question: Detect if a linked list has a cycle.
#
# Change: Return boolean on meeting

# %%
def hasCycle(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            return True
    return False

# %% [markdown]
# ✅ Variation 2: Find Cycle Start
#
# Question: Return node where cycle begins.
#
# Change: Reset slow to head

# %%
def detectCycle(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            break
    else:
        return None

    slow = head
    while slow != fast:
        slow = slow.next
        fast = fast.next
    return slow

# %% [markdown]
# ✅ Variation 3: Find Middle of Linked List
#
# Question: Return middle node.
#
# Change: No equality check

# %%
def middleNode(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
    return slow

# %% [markdown]
# ✅ Variation 4: Happy Number
#
# Question: Determine if a number is happy.
#
# Change: Pointer moves via function

# %%
def isHappy(n):
    def next_num(x):
        s = 0
        while x:
            s += (x % 10) ** 2
            x //= 10
        return s

    slow = fast = n
    while True:
        slow = next_num(slow)
        fast = next_num(next_num(fast))
        if slow == fast:
            break
    return slow == 1

# %% [markdown]
# ✅ Variation 5: Find Duplicate Number
#
# Question: Find duplicate in array [1..n].
#
# Change: Indices act as pointers

# %%
def findDuplicate(nums):
    slow = fast = nums[0]
    while True:
        slow = nums[slow]
        fast = nums[nums[fast]]
        if slow == fast:
            break

    slow = nums[0]
    while slow != fast:
        slow = nums[slow]
        fast = nums[fast]
    return slow

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Time: O(n)
#
# Space: O(1)
#
# Worst case when pointers traverse entire structure twice

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Forgetting fast.next check → crash
# ✔ Always guard fast pointer
#
# ❌ Returning meet point instead of cycle start
# ✔ Reset one pointer to head
#
# ❌ Using extra memory unnecessarily
# ✔ Trust pointer math
#
# ❌ Infinite loop in sequence problems
# ✔ Break only on equality
