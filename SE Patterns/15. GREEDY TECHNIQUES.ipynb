# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# Problems asking for maximum/minimum value, cost, profit, or coverage.
#
# Statements like: “choose optimal tasks”, “minimum coins”, “maximum profit”, “largest/smallest subset”.
#
# Input allows local choice → global optimum.
#
# Brute-force tries all subsets → O(2^n), fails for large n.
#
# Often sorted input or priority choice triggers greedy.

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Can we sort or prioritize items first?
#
# Is there a local best choice at each step?
#
# Are we asked to maximize/minimize a total metric?
#
# Can the problem be solved without backtracking?
#
# Do constraints allow independent decisions?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Pick the best local choice at each step.
#
# Repeat until done, ensuring local choices lead to global optimum.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
# assume items is a list of (value, weight) or (end, start) etc. as needed
items.sort(key=lambda x: x[0])  # sort by greedy criteria
result = []
for item in items:
    if condition(item, result):  # greedy selection check
        result.append(item)
return result

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Activity/Interval Selection → maximize non-overlapping intervals; sort by end-time.
#
# Minimum Coins / Change → pick largest denomination ≤ remaining; sort descending.
#
# Huffman / Frequency-based Encoding → pick smallest weights repeatedly; use min-heap.
#
# Fractional Knapsack → pick max value/weight ratio first; sort descending by ratio.
#
# Job Scheduling with Deadlines → pick highest profit first; sort by profit, place in latest free slot.

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Problem: Schedule max number of non-overlapping activities.
#
# Input: [(1,3),(2,5),(4,6),(6,8)]
#
# Step:
#
# Sort by end → [(1,3),(2,5),(4,6),(6,8)]
#
# Pick (1,3) → next compatible? (4,6) → pick → next (6,8) → pick
# Final output: [(1,3),(4,6),(6,8)]

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# 1. Activity/Interval Selection
#
# Variation: sort by end-time, select non-overlapping.

# %%
intervals = [(1,3),(2,5),(4,6),(6,8)]
intervals.sort(key=lambda x: x[1])
res = []
end = float('-inf')
for s,e in intervals:
    if s >= end:
        res.append((s,e))
        end = e
print(res)  # [(1,3),(4,6),(6,8)]

# %% [markdown]
# 2. Minimum Coins / Change
#
# Variation: sort descending, subtract largest.

# %%
coins = [25,10,5,1]
amount = 63
coins.sort(reverse=True)
res = []
for c in coins:
    while amount >= c:
        amount -= c
        res.append(c)
print(res)  # [25,25,10,1,1,1]

# %% [markdown]
# 3. Fractional Knapsack
#
# Variation: pick max value/weight ratio, allow fractions.

# %%
items = [(60,10),(100,20),(120,30)]
items.sort(key=lambda x: x[0]/x[1], reverse=True)
capacity = 50
total = 0
for v,w in items:
    if capacity >= w:
        total += v
        capacity -= w
    else:
        total += v * (capacity/w)
        break
print(total)  # 240.0

# %% [markdown]
# 4. Job Scheduling with Deadlines
#
# Variation: pick highest profit, schedule latest free slot.

# %%
jobs = [(2,100,2),(1,19,1),(2,27,2)]
jobs.sort(key=lambda x: -x[1])
slots = [False]*3
profit = 0
for d,p,_ in jobs:
    for i in range(d-1,-1,-1):
        if not slots[i]:
            slots[i] = True
            profit += p
            break
print(profit)  # 127

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Sorting dominates → O(n log n)
#
# Iteration over items → O(n)
#
# Space → O(n) for result / heap if used
#
# Worst-case: each item processed once, heap operations if min/max heap used

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Picking items in wrong order (sorting criteria wrong)
# ❌ Forgetting compatibility checks (interval overlap, capacity)
# ❌ Infinite loops in coin change while loop
# ❌ Using greedy where local choice ≠ global optimum (fractional knapsack vs 0-1 knapsack)
