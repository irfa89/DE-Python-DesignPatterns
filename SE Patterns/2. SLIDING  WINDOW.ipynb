# %% [markdown]
# **⭐ 1. What This Pattern Solves (INTERVIEW SIGNALS)**
#
# Keywords: subarray, substring, window, longest/shortest, at most / at least / exactly
#
# Input is array/string + contiguous range required
#
# Brute force = nested loops over all ranges → O(n²) (TLE)
#
# Optimizing a running range with constraints

# %% [markdown]
# **⭐ 2. Pattern Recognition Checklist**
#
# Is the data linear (array/string)?
#
# Are we optimizing a contiguous range?
#
# Do pointers only move forward?
#
# Is there a condition like ≤ k, ≥ k, exactly k?
#
# Can I reuse previous work when moving right?

# %% [markdown]
# **⭐ 3. Core Idea (MAX 2 LINES)**
#
# Expand right pointer to include elements.
#
# Shrink left pointer only when constraint breaks.

# %% [markdown]
# **⭐ 4. Canonical Template (🔥 MEMORIZE THIS 🔥)**

# %%
left = 0
state = {}
best = 0

for right in range(len(nums)):
    update(state, nums[right])

    while violates(state):
        remove(state, nums[left])
        left += 1

    best = max(best, right - left + 1)

# %% [markdown]
# **⭐ 5. Pattern Variations (COMPLETE LIST — MUST COVER ALL)**
#
# Fixed Window Size → window size constant, no while-loop
#
# Variable Window (At Most) → shrink while constraint violated
#
# Variable Window (Exactly) → derive from at-most windows
#
# Longest Valid Window → maximize window length
#
# Shortest Valid Window → minimize window length
#
# Expand-Only Window → no shrinking, monotonic condition
#
# Frequency-Based Window → hashmap / counter drives validity

# %% [markdown]
# **⭐ 6. Worked Example (Canonical Template)**
#
# Problem: Longest substring with at most 2 distinct characters
# Input: "eceba"
#
# Step-by-step:
#
# r=0 → e → window [e] valid
#
# r=1 → c → [e,c] valid
#
# r=2 → e → [e,c,e] valid → best=3
#
# r=3 → b → violates → shrink until valid
#
# r=4 → a → violates → shrink
#
# Output: 3

# %% [markdown]
# **⭐ 7. Variation-Based Solved Coding Questions (MANDATORY)**

# %% [markdown]
# **✅ Fixed Window Size**
#
# Q: Maximum sum of subarray of size k
# Variation: Fixed window
# Change: No shrink loop

# %%
window = 0
best = 0

for i in range(len(nums)):
    window += nums[i]
    if i >= k:
        window -= nums[i - k]
    if i >= k - 1:
        best = max(best, window)

# %% [markdown]
# **✅ Variable Window (At Most)**
#
# Q: Longest substring with at most k distinct characters
# Variation: At most
# Change: Shrink while len(freq) > k

# %%
left = 0
freq = {}
best = 0

for right, ch in enumerate(s):
    freq[ch] = freq.get(ch, 0) + 1

    while len(freq) > k:
        freq[s[left]] -= 1
        if freq[s[left]] == 0:
            del freq[s[left]]
        left += 1

    best = max(best, right - left + 1)

# %% [markdown]
# **✅ Variable Window (Exactly)**
#
# Q: Subarrays with exactly k distinct integers
# Variation: Exactly
# Change: exactly = atMost(k) − atMost(k−1)

# %%
def at_most(k):
    left = 0
    freq = {}
    count = 0

    for right, x in enumerate(nums):
        freq[x] = freq.get(x, 0) + 1
        while len(freq) > k:
            freq[nums[left]] -= 1
            if freq[nums[left]] == 0:
                del freq[nums[left]]
            left += 1
        count += right - left + 1
    return count

return at_most(k) - at_most(k - 1)

# %% [markdown]
# **✅ Shortest Valid Window**
#
# Q: Minimum window substring
# Variation: Shortest
# Change: Minimize window instead of max

# %%
need = Counter(t)
missing = len(t)
left = 0
best = float("inf")

for right, ch in enumerate(s):
    if need[ch] > 0:
        missing -= 1
    need[ch] -= 1

    while missing == 0:
        best = min(best, right - left + 1)
        need[s[left]] += 1
        if need[s[left]] > 0:
            missing += 1
        left += 1

# %% [markdown]
# **✅ Expand-Only Window**
#
# Q: Longest increasing subarray
# Variation: Expand-only
# Change: Reset left when order breaks

# %%
left = 0
best = 1

for right in range(1, len(nums)):
    if nums[right] <= nums[right - 1]:
        left = right
    best = max(best, right - left + 1)

# %% [markdown]
# **✅ Frequency-Based Window**
#
# Q: Longest repeating character replacement
# Variation: Frequency-driven
# Change: Validity via max frequency

# %%
left = 0
freq = {}
best = 0
maxf = 0

for right, ch in enumerate(s):
    freq[ch] = freq.get(ch, 0) + 1
    maxf = max(maxf, freq[ch])

    while (right - left + 1) - maxf > k:
        freq[s[left]] -= 1
        left += 1

    best = max(best, right - left + 1)

# %% [markdown]
# **⭐ 8. Time & Space Complexity (INTERVIEW READY)**
#
# Time: O(n) — each pointer moves forward once
#
# Space: O(1) to O(k) — depends on frequency map
#
# Worst case when window expands and shrinks fully

# %% [markdown]
# **⭐ 9. Common Failure Modes (WHY CANDIDATES FAIL)**
#
# ❌ Shrinking too early or too late
# ✔ Shrink only when constraint violated
#
# ❌ Forgetting window length formula
# ✔ Always right - left + 1
#
# ❌ Updating answer before window is valid
# ✔ Update after constraint satisfied
#
# ❌ Misusing exactly-k logic
# ✔ Use atMost(k) − atMost(k−1)
