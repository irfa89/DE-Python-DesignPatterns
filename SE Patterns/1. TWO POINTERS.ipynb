# %% [markdown]
# **⭐ 1. What This Pattern Solves**
#
# Search pairs in sorted arrays
#
# Detect duplicates / cycles
#
# Partition or reverse sections
#
# Sliding window
#
# Linked list manipulations
#
# Key idea: Two indices moving from start/end or different speeds.

# %% [markdown]
# **⭐ 2. SQL Equivalent**

# %%
# %sql
SELECT * 
FROM table t1
JOIN table t2
ON t1.value + t2.value = target;

# %% [markdown]
# **⭐ 3. Core Idea**
#
# Maintain two pointers
#
# Move pointers based on comparison/condition

# %% [markdown]
# **⭐ 4. Template Code**

# %%
lo, hi = 0, len(arr) - 1
while lo < hi:
    if condition(arr[lo], arr[hi]):
        # process pair
        lo += 1
        hi -= 1
    elif arr[lo] + arr[hi] < target:
        lo += 1
    else:
        hi -= 1

# %% [markdown]
# ⭐ 5. Example
#
# Array [1,2,3,7,8], target 10 → pair (2,8)

# %% [markdown]
# **⭐ 6. Mini Practice Problems**
#
# Pair sum = target
#
# Remove duplicates in sorted array
#
# Container with most water

# %% [markdown]
# **⭐ 7. Full DE Problem**
#
# Merge two sorted datasets efficiently using pointers

# %% [markdown]
# **⭐ 8. Time & Space Complexity**
#
# Time: O(n)
#
# Space: O(1)

# %% [markdown]
# **⭐ 9. Common Pitfalls**
#
# Off-by-one errors
#
# Forgetting to move pointers correctly
