# %% [markdown]
# **1. Fixed-size Top-K**

# %% [markdown]
# 1.1 K Largest Elements in an Array
#
# Problem Statement
# Given an integer array nums and an integer k, return the k largest elements in any order.
#
# Sample Test Cases
# Input: nums = [3,2,1,5,6,4], k = 2
# Output: [6,5]
#
# Input: nums = [1], k = 1
# Output: [1]

# %% [markdown]
# 1.2 K Smallest Elements
#
# Problem Statement
# Return the k smallest elements from an array.
#
# Sample Test Cases
# Input: nums = [7,10,4,3,20,15], k = 3
# Output: [3,4,7]
#
# Input: nums = [5], k = 1
# Output: [5]

# %% [markdown]
# 1.3 K Closest Points to Origin
#
# Problem Statement
# Given a list of points (x, y), return the k closest points to the origin.
#
# Sample Test Cases
# Input: points = [[1,3],[-2,2]], k = 1
# Output: [[-2,2]]
#
# Input: points = [[0,1]], k = 1
# Output: [[0,1]]

# %% [markdown]
# 1.4 K Most Frequent Elements
#
# Problem Statement
# Return the k most frequent elements in the array.
#
# Sample Test Cases
# Input: nums = [1,1,1,2,2,3], k = 2
# Output: [1,2]
#
# Input: nums = [1], k = 1
# Output: [1]

# %% [markdown]
# 1.5 Kth Largest Element
#
# Problem Statement
# Find the kth largest element in an unsorted array.
#
# Sample Test Cases
# Input: nums = [3,2,3,1,2,4,5,5,6], k = 4
# Output: 4
#
# Input: nums = [1], k = 1
# Output: 1

# %% [markdown]
# **2. Streaming Median**

# %% [markdown]
# 2.1 Median of Data Stream
#
# Problem Statement
# Design a data structure that supports adding numbers and finding the median.
#
# Sample Test Cases
# Input: add [1,2], findMedian
# Output: 1.5
#
# Input: add [1], findMedian
# Output: 1

# %% [markdown]
# 2.2 Sliding Stream Median
#
# Problem Statement
# Given a stream of integers, return the median after each insertion.
#
# Sample Test Cases
# Input: [5,15,1,3]
# Output: [5,10,5,4]
#
# Input: [1]
# Output: [1]

# %% [markdown]
# 2.3 Median After Each Prefix
#
# Problem Statement
# Return the median of the array after each prefix insertion.
#
# Sample Test Cases
# Input: [2,4,6]
# Output: [2,3,4]
#
# Input: [10]
# Output: [10]

# %% [markdown]
# 2.4 Median in Infinite Stream
#
# Problem Statement
# Continuously read integers and report the median at any time.
#
# Sample Test Cases
# Input: [1,5,2,10]
# Output: 3.5
#
# Input: [7]
# Output: 7

# %% [markdown]
# 2.5 Running Median with Negatives
#
# Problem Statement
# Support median queries on a stream that may contain negative numbers.
#
# Sample Test Cases
# Input: [-5,-10,0]
# Output: -5
#
# Input: [-1]
# Output: -1

# %% [markdown]
# **3. Merge K Sorted Arrays**

# %% [markdown]
# 3.1 Merge K Sorted Lists
#
# Problem Statement
# Merge k sorted lists into one sorted list.
#
# Sample Test Cases
# Input: [[1,4,5],[1,3,4],[2,6]]
# Output: [1,1,2,3,4,4,5,6]
#
# Input: [[]]
# Output: []

# %% [markdown]
# 3.2 Merge K Sorted Arrays
#
# Problem Statement
# Merge multiple sorted arrays into a single sorted array.
#
# Sample Test Cases
# Input: [[1,3],[2,4]]
# Output: [1,2,3,4]
#
# Input: []
# Output: []

# %% [markdown]
# 3.3 Smallest Range Covering K Lists
#
# Problem Statement
# Find the smallest range that includes at least one number from each list.
#
# Sample Test Cases
# Input: [[4,10,15],[1,5,20],[3,12]]
# Output: [3,5]
#
# Input: [[1],[2],[3]]
# Output: [1,3]

# %% [markdown]
# 3.4 Kth Smallest Across Sorted Lists
#
# Problem Statement
# Find the kth smallest number across multiple sorted lists.
#
# Sample Test Cases
# Input: [[2,6,8],[3,6,7],[1,3,4]], k = 5
# Output: 4
#
# Input: [[1]], k = 1
# Output: 1

# %% [markdown]
# 3.5 Merge Sorted Iterators
#
# Problem Statement
# Merge multiple sorted iterators into one sorted output.
#
# Sample Test Cases
# Input: [[1,2],[3,4]]
# Output: [1,2,3,4]
#
# Input: [[]]
# Output: []

# %% [markdown]
# **4. Sliding Window Maximum / Minimum**

# %% [markdown]
# 4.1 Sliding Window Maximum
#
# Problem Statement
# Return the maximum value in each sliding window of size k.
#
# Sample Test Cases
# Input: nums = [1,3,-1,-3,5,3,6,7], k = 3
# Output: [3,3,5,5,6,7]
#
# Input: nums = [1], k = 1
# Output: [1]

# %% [markdown]
# 4.2 Sliding Window Minimum
#
# Problem Statement
# Return the minimum value in each sliding window.
#
# Sample Test Cases
# Input: nums = [4,2,12,3], k = 2
# Output: [2,2,3]
#
# Input: nums = [5], k = 1
# Output: [5]

# %% [markdown]
# 4.3 Max of All Subarrays of Size K
#
# Problem Statement
# Classic sliding window max using heap or deque.
#
# Sample Test Cases
# Input: [10,5,2,7,8,7], k = 3
# Output: [10,7,8,8]
#
# Input: [1], k = 1
# Output: [1]

# %% [markdown]
# 4.4 Min Window Cost
#
# Problem Statement
# Find minimum element in every window of size k.
#
# Sample Test Cases
# Input: [8,5,10,7], k = 2
# Output: [5,5,7]
#
# Input: [3], k = 1
# Output: [3]

# %% [markdown]
# 4.5 Window Peak Tracking
#
# Problem Statement
# Track max element while sliding window moves.
#
# Sample Test Cases
# Input: [9,3,5,1], k = 2
# Output: [9,5,5]
#
# Input: [2], k = 1
# Output: [2]

# %% [markdown]
# **5. Custom Comparator**

# %% [markdown]
# 5.1 Reorder Strings by Length
#
# Problem Statement
# Sort strings by length using a heap.
#
# Sample Test Cases
# Input: ["a","abc","ab"]
# Output: ["a","ab","abc"]
#
# Input: ["x"]
# Output: ["x"]

# %% [markdown]
# 5.2 Sort by Frequency Then Value
#
# Problem Statement
# Sort numbers by frequency, breaking ties by value.
#
# Sample Test Cases
# Input: [1,1,2,2,2,3]
# Output: [3,1,1,2,2,2]
#
# Input: [5]
# Output: [5]

# %% [markdown]
# 5.3 Custom Priority Task Scheduler
#
# Problem Statement
# Schedule tasks based on priority and timestamp.
#
# Sample Test Cases
# Input: [(1,10),(2,5)]
# Output: [(2,5),(1,10)]
#
# Input: [(1,1)]
# Output: [(1,1)]

# %% [markdown]
# 5.4 Closest Value with Tie-Breaker
#
# Problem Statement
# Return value closest to target; break ties by smaller value.
#
# Sample Test Cases
# Input: nums = [4,7,10], target = 6
# Output: 7
#
# Input: nums = [5], target = 5
# Output: 5

# %% [markdown]
# 5.5 Sort Points by Distance Then X
#
# Problem Statement
# Sort points by distance to origin, break ties by x-coordinate.
#
# Sample Test Cases
# Input: [(1,1),(2,2),(1,2)]
# Output: [(1,1),(1,2),(2,2)]
#
# Input: [(0,0)]
# Output: [(0,0)]
