# %% [markdown]
# **1. Frequency Counting**

# %% [markdown]
# 1. First Unique Character in a String
#
# Problem Statement
# Given a string s, return the index of the first non-repeating character. If no such character exists, return -1.
#
# Sample Test Cases
# Input: s = "leetcode"
# Output: 0
#
# Input: s = "aabb"
# Output: -1

# %%
s1 = "leetcode" # Output: 0
s2 = "aabb"     # Output: -1

def unique_char(s):
    freq = {}
    for ch in s:
        freq[ch] = freq.get(ch,0) + 1
    for i,ch in enumerate(s):
        if ch in freq and freq[ch] == 1:
            return i
        else:
            return -1

print(unique_char(s1))
print(unique_char(s2))

# %% [markdown]
# 2. Majority Element
#
# Problem Statement
# Given an integer array nums, return the element that appears more than ⌊n / 2⌋ times. You may assume that a majority element always exists.
#
# Sample Test Cases
# Input: nums = [3, 2, 3]
# Output: 3
#
# Input: nums = [2, 2, 1, 1, 1, 2, 2]
# Output: 2

# %%
nums1 = [3, 2, 3] # Output: 3
nums2 = [2, 2, 1, 1, 1, 2, 2] #Output: 2

def max_occurence(nums):
    freq = {}
    for num in nums:
        freq[num] = freq.get(num,0) + 1
    max_value = max(freq.values())
    # return [k for k, v in freq.items() if v == max_value]
    return max(freq, key=freq.get)

print(max_occurence(nums1))
print(max_occurence(nums2))

# %%
from collections import Counter

def max_occurrence(nums):
    return Counter(nums).most_common(1)[0][0]

# %%
from collections import Counter

def max_occurrence(nums):
    freq = Counter(nums)
    max_freq = max(freq.values())
    return [num for num, cnt in freq.items() if cnt == max_freq]

# %% [markdown]
# 3. Check If Two Strings Are Anagrams
#
# Problem Statement
# Given two strings s and t, return true if t is an anagram of s, otherwise return false.
#
# Sample Test Cases
# Input: s = "anagram", t = "nagaram"
# Output: true
#
# Input: s = "rat", t = "car"
# Output: false

# %% [markdown]
# 4. Top K Frequent Elements
#
# Problem Statement
# Given an integer array nums and an integer k, return the k most frequent elements. The answer can be returned in any order.
#
# Sample Test Cases
# Input: nums = [1,1,1,2,2,3], k = 2
# Output: [1,2]
#
# Input: nums = [4,4,4,6,6,7], k = 1
# Output: [4]

# %%
def top_most_freq(nums, k):
    freq = {}

    for n in nums:
        freq[n] = freq.get(n, 0) + 1

    # Buckets where index = frequency
    buckets = [[] for _ in range(len(nums) + 1)]

    for num, count in freq.items():
        buckets[count].append(num)

    res = []
    for i in range(len(buckets) - 1, 0, -1):
        for num in buckets[i]:
            res.append(num)
            if len(res) == k:
                return res

# %% [markdown]
# 5. Valid Sudoku (Frequency Check)
#
# Problem Statement
# Given a 9×9 Sudoku board, determine if it is valid. A board is valid if each row, each column, and each 3×3 sub-box contains the digits 1–9 without repetition. Empty cells are represented by ".".
#
# Sample Test Cases
# Input:
# board =
# [["5","3",".",".","7",".",".",".","."],
# ["6",".",".","1","9","5",".",".","."],
# [".","9","8",".",".",".",".","6","."],
# ["8",".",".",".","6",".",".",".","3"],
# ["4",".",".","8",".","3",".",".","1"],
# ["7",".",".",".","2",".",".",".","6"],
# [".","6",".",".",".",".","2","8","."],
# [".",".",".","4","1","9",".",".","5"],
# [".",".",".",".","8",".",".","7","9"]]
#
# Output: true
#
# Input:
# board =
# [["8","3",".",".","7",".",".",".","."],
# ["6",".",".","1","9","5",".",".","."],
# [".","9","8",".",".",".",".","6","."],
# ["8",".",".",".","6",".",".",".","3"],
# ["4",".",".","8",".","3",".",".","1"],
# ["7",".",".",".","2",".",".",".","6"],
# [".","6",".",".",".",".","2","8","."],
# [".",".",".","4","1","9",".",".","5"],
# [".",".",".",".","8",".",".","7","9"]]
#
# Output: false

# %% [markdown]
# **2. Index Mapping**

# %% [markdown]
# 1. Two Sum
#
# Problem Statement
# Given an array of integers nums and an integer target, return the indices of the two numbers such that they add up to target. You may assume that each input has exactly one solution, and you may not use the same element twice.
#
# Sample Test Cases
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]

# %%
nums1 = [2,7,11,15]
target1 = 9 # Output: [0,1]
nums2 = [3,2,4]
target2 = 6 # Output: [1,2]

def two_sum(nums,target):
    freq = {}
    for i,ch in enumerate(nums):
        compliment = target - ch
        if compliment in freq:
            return [freq[compliment], i]
        else:
            freq[ch] = i
    return -1

print(two_sum(nums1,target1))
print(two_sum(nums2,target2))

# %% [markdown]
# 2. First Repeating Element Index
#
# Problem Statement
# Given an array of integers nums, return the index of the first element that repeats. If no element repeats, return -1. The index should correspond to the first occurrence of the repeating value.
#
# Sample Test Cases
# Input: nums = [1,2,3,4,1,5]
# Output: 4
#
# Input: nums = [1,2,3,4,5]
# Output: -1

# %%
nums1 = [1,2,3,4,1,5] # Output: 0
nums2 = [1,2,3,4,5]   # Output: -1

def repeat_elements(nums):
    freq = {}
    for i,n in enumerate(nums):
        freq[n] = freq.get(n,0) + 1
        if freq[n] > 1:
            return i
    return -1

print(repeat_elements(nums1))
print(repeat_elements(nums2))

# %%
def first_repeat_index(nums):
    seen = set()
    for i, n in enumerate(nums):
        if n in seen:
            return i
        seen.add(n)
    return -1
print(first_repeat_index(nums1))
print(first_repeat_index(nums2))

# %% [markdown]
# 3. Longest Substring Without Repeating Characters
#
# Problem Statement
# Given a string s, return the length of the longest substring without repeating characters.
#
# Sample Test Cases
# Input: s = "abcabcbb"
# Output: 3
#
# Input: s = "bbbbb"
# Output: 1

# %% [markdown]
# 4. Isomorphic Strings
#
# Problem Statement
# Given two strings s and t, determine if they are isomorphic. Two strings are isomorphic if the characters in s can be replaced to get t, with each character mapping to exactly one index pattern.
#
# Sample Test Cases
# Input: s = "egg", t = "add"
# Output: true
#
# Input: s = "foo", t = "bar"
# Output: false

# %% [markdown]
# 5. Word Pattern
#
# Problem Statement
# Given a pattern string and a space-separated string s, determine if s follows the same pattern. Each character in the pattern must map to exactly one word, and no two characters may map to the same word.
#
# Sample Test Cases
# Input: pattern = "abba", s = "dog cat cat dog"
# Output: true
#
# Input: pattern = "abba", s = "dog cat cat fish"
# Output: false

# %% [markdown]
# **3. Pair/Sum Lookup**

# %% [markdown]
# 1. Two Sum
#
# Problem Statement
# Given an array of integers nums and an integer target, return the indices of the two numbers such that they add up to the target. You may assume that each input has exactly one solution, and you may not use the same element twice.
#
# Sample Test Cases
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]

# %%
nums1 = [2,7,11,15]
target1 = 9                 # Output: [0,1]
nums2 = [3,2,4]
target2 = 6                 # Output: [1,2]

def pair_sum(nums,target):
    freq = {}
    for i,n in enumerate(nums):
        compliment = target - n
        if compliment in freq:
            return [freq[compliment], i]
        else:
            freq[n] = i
    return -1
print(pair_sum(nums1,target1))
print(pair_sum(nums2,target2))

# %% [markdown]
# 2. Count Pairs With Given Sum
#
# Problem Statement
# Given an integer array nums and an integer k, return the total number of unique pairs (i, j) such that i < j and nums[i] + nums[j] = k.
#
# Sample Test Cases
# Input: nums = [1,5,7,-1,5], k = 6
# Output: 3
#
# Input: nums = [1,1,1,1], k = 2
# Output: 6

# %% [markdown]
# 3. Subarray Sum Equals K
#
# Problem Statement
# Given an integer array nums and an integer k, return the total number of continuous subarrays whose sum equals k.
#
# Sample Test Cases
# Input: nums = [1,1,1], k = 2
# Output: 2
#
# Input: nums = [1,2,3], k = 3
# Output: 2

# %%
nums1 = [1,1,1]
k1 = 2 # Output: 2

nums2 = [1,2,3]
k2 = 3 # Output: 2

from collections import defaultdict

def subarr_sum(nums, k):
    freq = defaultdict(int)
    freq[0] = 1

    current_sum = 0
    count = 0

    for num in nums:
        current_sum += num
        count += freq[current_sum - k]
        freq[current_sum] += 1

    return count

print(subarr_sum(nums1,k1))
print(subarr_sum(nums1,k1))

# %% [markdown]
# 4. Four Sum II
#
# Problem Statement
# Given four integer arrays nums1, nums2, nums3, and nums4, return the number of tuples (i, j, k, l) such that
# nums1[i] + nums2[j] + nums3[k] + nums4[l] = 0.
#
# Sample Test Cases
# Input: nums1 = [1,2], nums2 = [-2,-1], nums3 = [-1,2], nums4 = [0,2]
# Output: 2
#
# Input: nums1 = [0], nums2 = [0], nums3 = [0], nums4 = [0]
# Output: 1

# %% [markdown]
# 5. Find Pair With Given Difference
#
# Problem Statement
# Given an integer array nums and an integer k, determine if there exists a pair of distinct indices (i, j) such that |nums[i] − nums[j]| = k.
#
# Sample Test Cases
# Input: nums = [1,5,3,4,2], k = 2
# Output: true
#
# Input: nums = [1,2,3,4,5], k = 10
# Output: false

# %% [markdown]
# **4. Sliding Window with Map**

# %% [markdown]
# 1. Longest Substring Without Repeating Characters
#
# Problem Statement
# Given a string s, return the length of the longest substring without repeating characters.
#
# Sample Test Cases
# Input: s = "abcabcbb"
# Output: 3
#
# Input: s = "pwwkew"
# Output: 3

# %%
s1 = "abcabcbb" # Output: 3
s2 = "pwwkew"   # Output: 3

def max_substr(s):
    l, freq, max_len = 0, {}, 0
    for r in range(len(s)):
        freq[s[r]] = freq.get(s[r],0) + 1
        while freq[s[r]] > 1:
            freq[s[l]] -= 1
            l += 1
        max_len = max(max_len, r - l + 1)
    return max_len

print(max_substr(s1))
print(max_substr(s2))

# %% [markdown]
# 2. Longest Substring with At Most K Distinct Characters
#
# Problem Statement
# Given a string s and an integer k, return the length of the longest substring that contains at most k distinct characters.
#
# Sample Test Cases
# Input: s = "eceba", k = 2
# Output: 3
#
# Input: s = "aa", k = 1
# Output: 2

# %% [markdown]
# 3. Longest Repeating Character Replacement
#
# Problem Statement
# Given a string s and an integer k, return the length of the longest substring that can be obtained by replacing at most k characters so that all characters in the substring are the same.
#
# Sample Test Cases
# Input: s = "ABAB", k = 2
# Output: 4
#
# Input: s = "AABABBA", k = 1
# Output: 4

# %% [markdown]
# 4. Minimum Window Substring
#
# Problem Statement
# Given two strings s and t, return the minimum window substring of s such that every character in t (including duplicates) is included in the window. If no such window exists, return an empty string.
#
# Sample Test Cases
# Input: s = "ADOBECODEBANC", t = "ABC"
# Output: "BANC"
#
# Input: s = "a", t = "aa"
# Output: ""

# %% [markdown]
# 5. Longest Substring with At Most Two Distinct Characters
#
# Problem Statement
# Given a string s, return the length of the longest substring that contains at most two distinct characters.
#
# Sample Test Cases
# Input: s = "ccaabbb"
# Output: 5
#
# Input: s = "eceba"
# Output: 3

# %% [markdown]
# **5. Group By Key**

# %% [markdown]
# 1. Group Anagrams
#
# Problem Statement
# Given an array of strings strs, group the anagrams together. You can return the answer in any order.
#
# Sample Test Cases
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
# Output: [["eat","tea","ate"],["tan","nat"],["bat"]]
#
# Input: strs = [""]
# Output: [[""]]

# %% [markdown]
# 2. Group Strings by Length
#
# Problem Statement
# Given an array of strings strs, group the strings by their length. Return the grouped strings in any order.
#
# Sample Test Cases
# Input: strs = ["a","bb","ccc","dd","e"]
# Output: [["a","e"],["bb","dd"],["ccc"]]
#
# Input: strs = ["hello","hi","h"]
# Output: [["h"],["hi"],["hello"]]

# %%
s1 = ["a","bb","ccc","dd","e"]  # Output: [["a","e"],["bb","dd"],["ccc"]]
s2 =  ["hello","hi","h"]        # Output: [["h"],["hi"],["hello"]]

from collections import defaultdict

def group_by_len(s):
    grp = defaultdict(list)
    result = []
    for x in s:
        grp[len(x)].append(x)
    for k,v in grp.items():
        result.append(v)
    return result

print(group_by_len(s1))
print(group_by_len(s2))

# %%
from collections import defaultdict

def group_by_len(s):
    # Step 1: group by length
    grp = defaultdict(list)
    for x in s:
        grp[len(x)].append(x)
    
    # Step 2: return groups in ascending order of length
    return [grp[length] for length in sorted(grp)]

# %% [markdown]
# 3. Employees by Department
#
# Problem Statement
# Given a list of employees represented as (name, department), group the employee names by their department.
#
# Sample Test Cases
# Input: employees = [("Alice","HR"),("Bob","IT"),("Charlie","HR"),("David","IT")]
# Output: {"HR":["Alice","Charlie"],"IT":["Bob","David"]}
#
# Input: employees = [("Eve","Finance")]
# Output: {"Finance":["Eve"]}

# %% [markdown]
# 4. Group Numbers by Remainder
#
# Problem Statement
# Given an array of integers nums and an integer k, group the numbers based on their remainder when divided by k.
#
# Sample Test Cases
# Input: nums = [1,2,3,4,5,6], k = 3
# Output: {1:[1,4], 2:[2,5], 0:[3,6]}
#
# Input: nums = [7,14,21], k = 7
# Output: {0:[7,14,21]}

# %% [markdown]
# 5. Group Words by First Character
#
# Problem Statement
# Given an array of lowercase strings words, group the words by their starting character.
#
# Sample Test Cases
# Input: words = ["apple","ant","bat","ball","cat"]
# Output: {"a":["apple","ant"],"b":["bat","ball"],"c":["cat"]}
#
# Input: words = ["dog"]
# Output: {"d":["dog"]}

# %% [markdown]
# **6. Prefix Sum Mapping**

# %% [markdown]
# 1. Subarray Sum Equals K
#
# Problem Statement
# Given an integer array nums and an integer k, return the total number of continuous subarrays whose sum equals k.
#
# Sample Test Cases
# Input: nums = [1,1,1], k = 2
# Output: 2
#
# Input: nums = [1,2,3], k = 3
# Output: 2

# %% [markdown]
# 2. Contiguous Array
#
# Problem Statement
# Given a binary array nums, return the maximum length of a contiguous subarray with an equal number of 0s and 1s.
#
# Sample Test Cases
# Input: nums = [0,1]
# Output: 2
#
# Input: nums = [0,1,0]
# Output: 2

# %% [markdown]
# 3. Find Pivot Index
#
# Problem Statement
# Given an integer array nums, return the pivot index where the sum of the numbers to the left equals the sum of the numbers to the right. If multiple pivots exist, return the left-most index. If none exist, return -1.
#
# Sample Test Cases
# Input: nums = [1,7,3,6,5,6]
# Output: 3
#
# Input: nums = [1,2,3]
# Output: -1

# %% [markdown]
# 4. Subarray Sum Divisible by K
#
# Problem Statement
# Given an integer array nums and an integer k, return the number of contiguous subarrays whose sum is divisible by k.
#
# Sample Test Cases
# Input: nums = [4,5,0,-2,-3,1], k = 5
# Output: 7
#
# Input: nums = [5], k = 5
# Output: 1

# %% [markdown]
# 5. Count Subarrays with Sum Equals Target Using Prefix Sum Map
#
# Problem Statement
# Given an integer array nums and an integer target, count the number of subarrays where the sum of elements equals the target using a prefix sum map approach.
#
# Sample Test Cases
# Input: nums = [3,4,7,2,-3,1,4,2], target = 7
# Output: 4
#
# Input: nums = [1,2,3], target = 3
# Output: 2
