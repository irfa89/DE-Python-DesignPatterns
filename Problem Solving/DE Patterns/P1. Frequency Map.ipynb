# %%
events = ["200","200","404","500","200"]

# %%
freq = {}
for x in events:
    freq[x] = freq.get(x,0) + 1
freq

# %%
events = ["login", "logout", "login", "purchase", "login"]

# %%
freq = {}

for e in events:
    freq[e] = freq.get(e,0) + 1

freq

# %%
names = ["alice","bob","alice","sam"]

freq = {}
for n in names:
    freq[n] = freq.get(n,0) + 1
freq

# %%
fruit = "banana"
freq = {}
for ch in fruit:
    freq[ch] =  freq.get(ch,0) + 1
freq

# %%
errors = ["timeout","ok","timeout","fail"]

freq = {}
for e in errors:
    freq[e] = freq.get(e,0) + 1

freq

# %%
(user_id, transaction_id)
Input = 
[
  ("u1", "t1"),
  ("u2", "t2"),
  ("u1", "t3"),
  ("u3", "t4"),
  ("u2", "t5"),
  ("u1", "t6")
]
Expected =
{
  "u1": 3,
  "u2": 2,
  "u3": 1
}

# %%
transactions = [
  ("u1", "t1"),
  ("u2", "t2"),
  ("u1", "t3"),
  ("u3", "t4"),
  ("u2", "t5"),
  ("u1", "t6")
]

# %%
freq = {}
for u,t in transactions:
    freq[u] = freq.get(u,0) + 1
freq

# %%
logs = [
  {"user":"a", "status":200},
  {"user":"b", "status":200},
  {"user":"a", "status":500},
  {"user":"c", "status":200},
  {"user":"b", "status":500}
]

freq = {}

for l in logs:
    code = l["status"]
    freq[code] = freq.get(code,0) + 1
freq
