# %% [markdown]
# 🟢 Easy 1 — Preserve First Occurrence Order
#
# Problem
# Given a list of integers, remove duplicates while preserving the first occurrence order.
#
# Input [3, 1, 2, 3, 2, 4, 1]
# nums: List[int]
#
# Output : [3, 1, 2, 4]
# List[int]
#
# Constraints
#
# 1 ≤ len(nums) ≤ 10⁵

# %% [markdown]
# 🟢 Easy 2 — First Unique Element (Stream Order)
#
# Problem
# Return the first element that appears exactly once, respecting input order.
#
# Input : nums = [4, 5, 1, 2, 1, 4]
# nums: List[int]
#
# Output : 5
# int | None
#
# Constraints
#
# Single pass preferred

# %% [markdown]
# 🟢 Easy 3 — Character Frequency (Ordered)
#
# Problem
# Count character frequency in a string while preserving first appearance order.
#
# Input : s = "banana"
# s: str
#
# Output : OrderedDict([
#     ('b', 1),
#     ('a', 3),
#     ('n', 2)
# ])
#
# OrderedDict[str, int]

# %% [markdown]
# 🟢 Easy 4 — Deduplicate Events by Event ID
#
# Problem
# Given a list of event IDs, keep only the first occurrence, preserving order.
#
# Input
# events = ["login", "logout", "login", "purchase", "logout"]
# events: List[str]
#
# Output
# ["login", "logout", "purchase"]
# List[str]

# %% [markdown]
# 🟢 Easy 5 — Last Seen Timestamp per User
#
# Problem
# Given (user, timestamp) tuples, return the latest timestamp per user, ordered by last update time.
#
# Input
# events = [
#     ("u1", 100),
#     ("u2", 200),
#     ("u1", 300),
#     ("u3", 150),
#     ("u2", 400)
# ]
#
# events: List[Tuple[str, int]]
#
# Output
# OrderedDict([
#     ("u1", 300),
#     ("u3", 150),
#     ("u2", 400)
# ])
#
# OrderedDict[str, int]

# %% [markdown]
# 🟢 Easy 6 — Move Accessed Key to End
#
# Problem
# Simulate cache access: when a key is accessed, move it to the most recent position.
#
# Input keys = ["A", "B", "C", "A", "B", "D"]
#
# keys: List[str]
#
# Output ["C", "A", "B", "D"]
# List[str]

# %% [markdown]
# 🟡 Medium 1 — Implement LRU Cache (Capacity N)
#
# Problem
# Implement an LRU Cache with fixed capacity.
#
# Operations
#
# get(key)
#
# put(key, value)
#
# Constraints
#
# O(1) operations
#
# Evict least recently used key
#
# Input :
# put(1, 10)
# put(2, 20)
# get(1)
# put(3, 30)
# get(2)
#
# Output:
# get(1) → 10
# get(2) → -1

# %% [markdown]
# 🟡 Medium 2 — Deduplicate Logs with Recency Priority
#
# Problem
# Given logs (log_id, timestamp), keep only latest log per ID, ordered by most recent timestamp.
#
# Input :
# logs = [
#     ("L1", 100),
#     ("L2", 200),
#     ("L1", 300),
#     ("L3", 150),
#     ("L2", 400)
# ]
#
# logs: List[Tuple[str, int]]
#
# Output :
# OrderedDict([
#     ("L1", 300),
#     ("L3", 150),
#     ("L2", 400)
# ])
#
# OrderedDict[str, int]

# %% [markdown]
# 🟡 Medium 3 — Sliding Window Unique Tracker
#
# Problem
# Maintain the last K unique elements from a stream.
#
# Input:
# nums = [1, 2, 3, 1, 4, 2, 5]
# k = 3
#
# nums: List[int], k: int
#
# Output:
# [4, 2, 5]
# List[int]

# %% [markdown]
# 🟡 Medium 4 — Reorder Events by Latest Occurrence
#
# Problem
# Given a list of events, reorder them so that most recently seen events appear last, without duplicates.
#
# Input
# events = ["A", "B", "C", "A", "D", "B"]
# events: List[str]
#
# Output
# ["C", "A", "D", "B"]
# List[str]
