# %% [markdown]
# ✅ Easy 1 — Basic Frequency Count (Logs)
# Problem
#
# You are given a list of HTTP status codes from web logs. Count the frequency of each status code.
#
# Input
#
# statuses = [200, 200, 404, 500, 200, 404]
#
#
# Output
#
# {200: 3, 404: 2, 500: 1}
#
#
# Constraints
#
# Up to 1M log entries
#
# Order does not matter

# %% [markdown]
# ✅ Easy 2 — Most Common Event
# Problem
#
# Given a list of event names, return the most frequent event.
#
# Input
#
# events = ["login", "logout", "login", "purchase", "login"]
#
#
# Output
#
# "login"

# %% [markdown]
# ✅ Easy 3 — Character Frequency (Data Cleaning)
# Problem
#
# Count character frequency in a string, ignoring spaces.
#
# Input
#
# s = "data engineer"
#
#
# Output
#
# {'d':1,'a':2,'t':1,'e':3,'n':2,'g':1,'i':1,'r':1}

# %% [markdown]
# ✅ Easy 4 — Compare Two Frequency Distributions
# Problem
#
# Check if two lists have the same element frequency.
#
# Input
#
# a = [1,2,2,3]
# b = [2,1,3,2]
#
#
# Output
#
# True

# %% [markdown]
# ✅ Easy 5 — Count Words in a Sentence
# Problem
#
# Count word occurrences in a sentence.
#
# Input
#
# text = "spark is fast and spark is scalable"
#
#
# Output
#
# {'spark':2,'is':2,'fast':1,'and':1,'scalable':1}

# %% [markdown]
# ✅ Easy 6 — Remove Zero Counts
# Problem
#
# Remove keys with zero counts after decrementing.
#
# Input
#
# counts = Counter({"a":2,"b":1})
# decrements = ["a","b","b"]
#
#
# Output
#
# {'a':1}

# %% [markdown]
# 🔶 Medium 1 — Top-K Frequent Elements (Metrics)
# Problem
#
# Return the top k most frequent elements.
#
# Input
#
# nums = [1,1,1,2,2,3,3,3,3]
# k = 2
#
#
# Output
#
# [3,1]

# %% [markdown]
# 🔶 Medium 2 — Anagram Group Validation
# Problem
#
# Check if two strings are anagrams (case-insensitive).
#
# Input
#
# s1 = "Listen"
# s2 = "Silent"
#
#
# Output
#
# True

# %% [markdown]
# 🔶 Medium 3 — Log Volume Spike Detection
# Problem
#
# Find endpoints with request count > threshold.
#
# Input
#
# logs = ["/api/a","/api/b","/api/a","/api/a","/api/b"]
# threshold = 2
#
#
# Output
#
# ["/api/a"]

# %% [markdown]
# 🔶 Medium 4 — Counter Merge (Distributed Reduce)
# Problem
#
# Merge multiple partial counters from distributed jobs.
#
# Input
#
# counters = [
#     Counter({"a":2,"b":1}),
#     Counter({"a":1,"c":3})
# ]
#
#
# Output
#
# {'a':3,'b':1,'c':3}
